# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
import numpy as np

# ===== Load file =====
sheet_name = "NEES_Database__ACI_445_Punching"
file_path = '../데이터 베이스/ACI 318-14.xlsx'
df = pd.read_excel(file_path, sheet_name=sheet_name)

# ===== Extract data =====
pu = df["Pu [kN]"]   # Experimental values
vn = df["ACI 318-14"]        # Predicted values

# ===== Calculate R² =====
r2 = r2_score(pu, vn)
print(f"R² = {r2:.3f}")

# ===== Calculate Coefficient of Variation (CV) =====
ratio = pu / vn
cv = np.std(ratio, ddof=1) / np.mean(ratio)  # sample standard deviation / mean
print(f"Coefficient of Variation (CV) = {cv:.3f}")

# ===== Calculate Coefficient of Variation (CV) =====
ratio = pu / vn
cv = np.std(ratio, ddof=1) / np.mean(ratio)  # sample standard deviation / mean
print(f"Coefficient of Variation (CV) = {cv:.3f}")

# ===== Scatter plot =====
plt.figure(figsize=(7,7))
plt.scatter(pu, vn, alpha=0.7, label="Data")

# 1:1 line
max_val = max(pu.max(), vn.max())
plt.plot([0, max_val], [0, max_val], 'r--', label="1:1 Line")

plt.xlabel("Pu [kN] (Experimental)")
plt.ylabel("Vn [kN] (Predicted)")
plt.title(f"Pu vs Vn (R² = {r2:.3f})")
plt.legend()
plt.grid(True)
plt.axis("equal")

# ===== Axis range =====
plt.xlim(0, 2500)   # add 10% margin
plt.ylim(0, 2500)

# ===== Save to PDF =====
plt.savefig("ACI318.pdf", format="pdf", bbox_inches="tight")

plt.show()
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# R² = 0.762
# Coefficient of Variation (CV) = 0.335
# Coefficient of Variation (CV) = 0.335

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# ===== Load file =====
sheet_name = "NEES_Database__ACI_445_Punching"
file_path = '../데이터 베이스/Eurocode 2-19.xlsx'
df = pd.read_excel(file_path, sheet_name=sheet_name)

# ===== Extract data =====
pu = df["Pu [kN]"]   # Experimental values
vn = df["Vn"]        # Predicted values

# ===== Calculate R² =====
r2 = r2_score(pu, vn)
print(f"R² = {r2:.3f}")

# ===== Calculate Coefficient of Variation (CV) =====
ratio = pu / vn
cv = np.std(ratio, ddof=1) / np.mean(ratio)  # sample standard deviation / mean
print(f"Coefficient of Variation (CV) = {cv:.3f}")

# ===== Calculate Coefficient of Variation (CV) =====
ratio = pu / vn
cv = np.std(ratio, ddof=1) / np.mean(ratio)  # sample standard deviation / mean
print(f"Coefficient of Variation (CV) = {cv:.3f}")

# ===== Scatter plot =====
plt.figure(figsize=(7,7))
plt.scatter(pu, vn, alpha=0.7, label="Data")

# 1:1 line
max_val = max(pu.max(), vn.max())
plt.plot([0, max_val], [0, max_val], 'r--', label="1:1 Line")

plt.xlabel("Pu [kN] (Experimental)")
plt.ylabel("Vn [kN] (Predicted)")
plt.title(f"Pu vs Vn (R² = {r2:.3f})")
plt.legend()
plt.grid(True)
plt.axis("equal")

# ===== Axis range =====
plt.xlim(0, 2500)   # add 10% margin
plt.ylim(0, 2500)

# ===== Save to PDF =====
plt.savefig("Eurocode 2-19.pdf", format="pdf", bbox_inches="tight")

plt.show()
# Out:
# c:\Users\yjy98\Documents\Punching-shear\venv\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# R² = 0.670
# Coefficient of Variation (CV) = nan
# Coefficient of Variation (CV) = nan

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# ===== Load file =====
sheet_name = "NEES_Database__ACI_445_Punching"
file_path = '../데이터 베이스/CSA.xlsx'
df = pd.read_excel(file_path, sheet_name=sheet_name)

# ===== Extract data =====
pu = df["Pu [kN]"]   # Experimental values
vn = df["Vc"]        # Predicted values

# ===== Calculate R² =====
r2 = r2_score(pu, vn)
print(f"R² = {r2:.3f}")

# ===== Calculate Coefficient of Variation (CV) =====
ratio = pu / vn
cv = np.std(ratio, ddof=1) / np.mean(ratio)  # sample standard deviation / mean
print(f"Coefficient of Variation (CV) = {cv:.3f}")

# ===== Calculate Coefficient of Variation (CV) =====
ratio = pu / vn
cv = np.std(ratio, ddof=1) / np.mean(ratio)  # sample standard deviation / mean
print(f"Coefficient of Variation (CV) = {cv:.3f}")

# ===== Scatter plot =====
plt.figure(figsize=(7,7))
plt.scatter(pu, vn, alpha=0.7, label="Data")

# 1:1 line
max_val = max(pu.max(), vn.max())
plt.plot([0, max_val], [0, max_val], 'r--', label="1:1 Line")

plt.xlabel("Pu [kN] (Experimental)")
plt.ylabel("Vn [kN] (Predicted)")
plt.title(f"Pu vs Vn (R² = {r2:.3f})")
plt.legend()
plt.grid(True)
plt.axis("equal")

# ===== Axis range =====
plt.xlim(0, 2500)   # add 10% margin
plt.ylim(0, 2500)

# ===== Save to PDF =====
plt.savefig("CSA.pdf", format="pdf", bbox_inches="tight")

plt.show()
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# R² = 0.786
# Coefficient of Variation (CV) = 0.354
# Coefficient of Variation (CV) = 0.354

# %% [markdown]
# # CV

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score

# ===== Load file =====
sheet_name = "NEES_Database__ACI_445_Punching"
file_path = '../데이터 베이스/ACI 318-14.xlsx'
df = pd.read_excel(file_path, sheet_name=sheet_name)

# ===== Extract data =====
pu = df["Pu [kN]"]   # Experimental values
vn = df["ACI 318-14"]        # Predicted values

# ===== 데이터 확인 =====
print("=== 데이터 확인 ===")
print(f"Pu 데이터 개수: {len(pu)}")
print(f"Vn 데이터 개수: {len(vn)}")
print(f"Pu NaN 개수: {pu.isna().sum()}")
print(f"Vn NaN 개수: {vn.isna().sum()}")
print(f"Pu = 0인 개수: {(pu == 0).sum()}")
print(f"Vn = 0인 개수: {(vn == 0).sum()}")
print(f"Pu 최소값: {pu.min()}")
print(f"Vn 최소값: {vn.min()}")

# ===== 결측값 및 0값 제거 =====
# NaN 값이나 0값이 있는 행을 제거
mask = (~pu.isna()) & (~vn.isna()) & (pu > 0) & (vn > 0)
pu_clean = pu[mask]
vn_clean = vn[mask]

print(f"\n정리 후 데이터 개수: {len(pu_clean)}")

# ===== Calculate R² =====
r2 = r2_score(pu_clean, vn_clean)
print(f"R² = {r2:.3f}")

# ===== Calculate Coefficient of Variation (CV) =====
ratio = pu_clean / vn_clean
print(f"\nRatio 통계:")
print(f"평균: {np.mean(ratio):.3f}")
print(f"표준편차: {np.std(ratio, ddof=1):.3f}")
print(f"NaN 개수: {np.isnan(ratio).sum()}")

# CV 계산
if np.mean(ratio) != 0 and not np.isnan(np.mean(ratio)):
    cv = np.std(ratio, ddof=1) / np.mean(ratio)
    print(f"Coefficient of Variation (CV) = {cv:.3f}")
else:
    print("CV 계산 불가: 평균이 0이거나 NaN입니다.")

# ===== Scatter plot =====
plt.figure(figsize=(7,7))
plt.scatter(pu_clean, vn_clean, alpha=0.7, label="Data")

# 1:1 line
max_val = max(pu_clean.max(), vn_clean.max())
plt.plot([0, max_val], [0, max_val], 'r--', label="1:1 Line")

plt.xlabel("Pu [kN] (Experimental)")
plt.ylabel("Vn [kN] (Predicted)")
plt.title(f"Pu vs Vn (R² = {r2:.3f})")
plt.legend()
plt.grid(True)
plt.axis("equal")

# ===== Axis range =====
plt.xlim(0, 2500)
plt.ylim(0, 2500)

# ===== Save to PDF =====
plt.savefig("Eurocode 2-19.pdf", format="pdf", bbox_inches="tight")

plt.show()

# ===== 추가 통계 정보 =====
print(f"\n=== 추가 통계 정보 ===")
print(f"평균 비율 (Pu/Vn): {np.mean(ratio):.3f}")
print(f"표준편차: {np.std(ratio, ddof=1):.3f}")
print(f"변동계수 (CV): {cv:.3f}")
print(f"최소 비율: {np.min(ratio):.3f}")
print(f"최대 비율: {np.max(ratio):.3f}")
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# === 데이터 확인 ===
# Pu 데이터 개수: 519
# Vn 데이터 개수: 519
# Pu NaN 개수: 0
# Vn NaN 개수: 0
# Pu = 0인 개수: 0
# Vn = 0인 개수: 0
# Pu 최소값: 24
# Vn 최소값: 12.889209084379313
#
# 정리 후 데이터 개수: 519
# R² = 0.762
#
# Ratio 통계:
# 평균: 1.626
# 표준편차: 0.545
# NaN 개수: 0
# Coefficient of Variation (CV) = 0.335
# === 추가 통계 정보 ===
# 평균 비율 (Pu/Vn): 1.626
# 표준편차: 0.545
# 변동계수 (CV): 0.335
# 최소 비율: 0.608
# 최대 비율: 5.478

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score

# ===== Load file =====
sheet_name = "NEES_Database__ACI_445_Punching"
file_path = '../데이터 베이스/Eurocode 2-19.xlsx'
df = pd.read_excel(file_path, sheet_name=sheet_name)

# ===== Extract data =====
pu = df["Pu [kN]"]   # Experimental values
vn = df["Vn"]        # Predicted values

# ===== 데이터 확인 =====
print("=== 데이터 확인 ===")
print(f"Pu 데이터 개수: {len(pu)}")
print(f"Vn 데이터 개수: {len(vn)}")
print(f"Pu NaN 개수: {pu.isna().sum()}")
print(f"Vn NaN 개수: {vn.isna().sum()}")
print(f"Pu = 0인 개수: {(pu == 0).sum()}")
print(f"Vn = 0인 개수: {(vn == 0).sum()}")
print(f"Pu 최소값: {pu.min()}")
print(f"Vn 최소값: {vn.min()}")

# ===== 결측값 및 0값 제거 =====
# NaN 값이나 0값이 있는 행을 제거
mask = (~pu.isna()) & (~vn.isna()) & (pu > 0) & (vn > 0)
pu_clean = pu[mask]
vn_clean = vn[mask]

print(f"\n정리 후 데이터 개수: {len(pu_clean)}")

# ===== Calculate R² =====
r2 = r2_score(pu_clean, vn_clean)
print(f"R² = {r2:.3f}")

# ===== Calculate Coefficient of Variation (CV) =====
ratio = pu_clean / vn_clean
print(f"\nRatio 통계:")
print(f"평균: {np.mean(ratio):.3f}")
print(f"표준편차: {np.std(ratio, ddof=1):.3f}")
print(f"NaN 개수: {np.isnan(ratio).sum()}")

# CV 계산
if np.mean(ratio) != 0 and not np.isnan(np.mean(ratio)):
    cv = np.std(ratio, ddof=1) / np.mean(ratio)
    print(f"Coefficient of Variation (CV) = {cv:.3f}")
else:
    print("CV 계산 불가: 평균이 0이거나 NaN입니다.")

# ===== Scatter plot =====
plt.figure(figsize=(7,7))
plt.scatter(pu_clean, vn_clean, alpha=0.7, label="Data")

# 1:1 line
max_val = max(pu_clean.max(), vn_clean.max())
plt.plot([0, max_val], [0, max_val], 'r--', label="1:1 Line")

plt.xlabel("Pu [kN] (Experimental)")
plt.ylabel("Vn [kN] (Predicted)")
plt.title(f"Pu vs Vn (R² = {r2:.3f})")
plt.legend()
plt.grid(True)
plt.axis("equal")

# ===== Axis range =====
plt.xlim(0, 2500)
plt.ylim(0, 2500)

# ===== Save to PDF =====
plt.savefig("Eurocode 2-19.pdf", format="pdf", bbox_inches="tight")

plt.show()

# ===== 추가 통계 정보 =====
print(f"\n=== 추가 통계 정보 ===")
print(f"평균 비율 (Pu/Vn): {np.mean(ratio):.3f}")
print(f"표준편차: {np.std(ratio, ddof=1):.3f}")
print(f"변동계수 (CV): {cv:.3f}")
print(f"최소 비율: {np.min(ratio):.3f}")
print(f"최대 비율: {np.max(ratio):.3f}")
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# === 데이터 확인 ===
# Pu 데이터 개수: 519
# Vn 데이터 개수: 519
# Pu NaN 개수: 0
# Vn NaN 개수: 0
# Pu = 0인 개수: 0
# Vn = 0인 개수: 55
# Pu 최소값: 24
# Vn 최소값: 0.0
#
# 정리 후 데이터 개수: 464
# R² = 0.780
#
# Ratio 통계:
# 평균: 0.786
# 표준편차: 0.291
# NaN 개수: 0
# Coefficient of Variation (CV) = 0.370
# === 추가 통계 정보 ===
# 평균 비율 (Pu/Vn): 0.786
# 표준편차: 0.291
# 변동계수 (CV): 0.370
# 최소 비율: 0.288
# 최대 비율: 2.869

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score

# ===== Load file =====
sheet_name = "NEES_Database__ACI_445_Punching"
file_path = '../데이터 베이스/CSA.xlsx'
df = pd.read_excel(file_path, sheet_name=sheet_name)

# ===== Extract data =====
pu = df["Pu [kN]"]   # Experimental values
vn = df["Vc"]        # Predicted values

# ===== 데이터 확인 =====
print("=== 데이터 확인 ===")
print(f"Pu 데이터 개수: {len(pu)}")
print(f"Vn 데이터 개수: {len(vn)}")
print(f"Pu NaN 개수: {pu.isna().sum()}")
print(f"Vn NaN 개수: {vn.isna().sum()}")
print(f"Pu = 0인 개수: {(pu == 0).sum()}")
print(f"Vn = 0인 개수: {(vn == 0).sum()}")
print(f"Pu 최소값: {pu.min()}")
print(f"Vn 최소값: {vn.min()}")

# ===== 결측값 및 0값 제거 =====
# NaN 값이나 0값이 있는 행을 제거
mask = (~pu.isna()) & (~vn.isna()) & (pu > 0) & (vn > 0)
pu_clean = pu[mask]
vn_clean = vn[mask]

print(f"\n정리 후 데이터 개수: {len(pu_clean)}")

# ===== Calculate R² =====
r2 = r2_score(pu_clean, vn_clean)
print(f"R² = {r2:.3f}")

# ===== Calculate Coefficient of Variation (CV) =====
ratio = pu_clean / vn_clean
print(f"\nRatio 통계:")
print(f"평균: {np.mean(ratio):.3f}")
print(f"표준편차: {np.std(ratio, ddof=1):.3f}")
print(f"NaN 개수: {np.isnan(ratio).sum()}")

# CV 계산
if np.mean(ratio) != 0 and not np.isnan(np.mean(ratio)):
    cv = np.std(ratio, ddof=1) / np.mean(ratio)
    print(f"Coefficient of Variation (CV) = {cv:.3f}")
else:
    print("CV 계산 불가: 평균이 0이거나 NaN입니다.")

# ===== Scatter plot =====
plt.figure(figsize=(7,7))
plt.scatter(pu_clean, vn_clean, alpha=0.7, label="Data")

# 1:1 line
max_val = max(pu_clean.max(), vn_clean.max())
plt.plot([0, max_val], [0, max_val], 'r--', label="1:1 Line")

plt.xlabel("Pu [kN] (Experimental)")
plt.ylabel("Vn [kN] (Predicted)")
plt.title(f"Pu vs Vn (R² = {r2:.3f})")
plt.legend()
plt.grid(True)
plt.axis("equal")

# ===== Axis range =====
plt.xlim(0, 2500)
plt.ylim(0, 2500)

# ===== Save to PDF =====
plt.savefig("Eurocode 2-19.pdf", format="pdf", bbox_inches="tight")

plt.show()

# ===== 추가 통계 정보 =====
print(f"\n=== 추가 통계 정보 ===")
print(f"평균 비율 (Pu/Vn): {np.mean(ratio):.3f}")
print(f"표준편차: {np.std(ratio, ddof=1):.3f}")
print(f"변동계수 (CV): {cv:.3f}")
print(f"최소 비율: {np.min(ratio):.3f}")
print(f"최대 비율: {np.max(ratio):.3f}")
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# === 데이터 확인 ===
# Pu 데이터 개수: 519
# Vn 데이터 개수: 519
# Pu NaN 개수: 0
# Vn NaN 개수: 0
# Pu = 0인 개수: 0
# Vn = 0인 개수: 0
# Pu 최소값: 24
# Vn 최소값: 11.020273767144317
#
# 정리 후 데이터 개수: 519
# R² = 0.786
#
# Ratio 통계:
# 평균: 1.681
# 표준편차: 0.594
# NaN 개수: 0
# Coefficient of Variation (CV) = 0.354
# === 추가 통계 정보 ===
# 평균 비율 (Pu/Vn): 1.681
# 표준편차: 0.594
# 변동계수 (CV): 0.354
# 최소 비율: 0.550
# 최대 비율: 4.805
